# %% [markdown]
# # Assignment 7
#
# Name: Aziz Sayyad
# Roll: 381069
# PRN: 22420090
# Batch: A3
#
# #### Develop a text preprocessing and analysis application using NLTK for tokenization, POS tagging, and basic NLP tasks.

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in C:\Users\Aziz\AppData\Roaming\Python\Python312\site-packages (3.9.1)
# Requirement already satisfied: click in C:\Users\Aziz\AppData\Roaming\Python\Python312\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in C:\Users\Aziz\AppData\Roaming\Python\Python312\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Aziz\AppData\Roaming\Python\Python312\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in C:\Users\Aziz\AppData\Roaming\Python\Python312\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in C:\Users\Aziz\AppData\Roaming\Python\Python312\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.probability import FreqDist
import string

# Downloading required datasets 
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Aziz\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
text = """
Natural Language Processing (NLP) is a branch of Artificial Intelligence.
It helps computers understand, interpret, and generate human language.
NLP is widely used in chatbots, translation systems, and sentiment analysis.
"""

print("Original Text:\n")
print(text)
# Out:
# Original Text:
#
#
# Natural Language Processing (NLP) is a branch of Artificial Intelligence.
# It helps computers understand, interpret, and generate human language.
# NLP is widely used in chatbots, translation systems, and sentiment analysis.

# %%
sentences = sent_tokenize(text)

print("Sentence Tokenization:\n")
for s in sentences:
    print(s)
# Out:
# Sentence Tokenization:
#
#
# Natural Language Processing (NLP) is a branch of Artificial Intelligence.
# It helps computers understand, interpret, and generate human language.
# NLP is widely used in chatbots, translation systems, and sentiment analysis.

# %%
words = word_tokenize(text)

print("Word Tokenization:\n")
print(words)
# Out:
# Word Tokenization:
#
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', 'It', 'helps', 'computers', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', '.', 'NLP', 'is', 'widely', 'used', 'in', 'chatbots', ',', 'translation', 'systems', ',', 'and', 'sentiment', 'analysis', '.']

# %%
stop_words = set(stopwords.words("english"))

filtered_words = [
    word for word in words
    if word.lower() not in stop_words and word not in string.punctuation
]

print("After Stopword Removal:\n")
print(filtered_words)
# Out:
# After Stopword Removal:
#
# ['Natural', 'Language', 'Processing', 'NLP', 'branch', 'Artificial', 'Intelligence', 'helps', 'computers', 'understand', 'interpret', 'generate', 'human', 'language', 'NLP', 'widely', 'used', 'chatbots', 'translation', 'systems', 'sentiment', 'analysis']

# %%
pos_tags = nltk.pos_tag(words)

print("POS Tagging:\n")
print(pos_tags)
# Out:
# POS Tagging:
#
# [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('(', '('), ('NLP', 'NNP'), (')', ')'), ('is', 'VBZ'), ('a', 'DT'), ('branch', 'NN'), ('of', 'IN'), ('Artificial', 'JJ'), ('Intelligence', 'NNP'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('computers', 'NNS'), ('understand', 'VBP'), (',', ','), ('interpret', 'JJ'), (',', ','), ('and', 'CC'), ('generate', 'VB'), ('human', 'JJ'), ('language', 'NN'), ('.', '.'), ('NLP', 'NNP'), ('is', 'VBZ'), ('widely', 'RB'), ('used', 'VBN'), ('in', 'IN'), ('chatbots', 'NNS'), (',', ','), ('translation', 'NN'), ('systems', 'NNS'), (',', ','), ('and', 'CC'), ('sentiment', 'NN'), ('analysis', 'NN'), ('.', '.')]

# %%
fdist = FreqDist(filtered_words)

print("Most Common Words:\n")
print(fdist.most_common(5))
# Out:
# Most Common Words:
#
# [('NLP', 2), ('Natural', 1), ('Language', 1), ('Processing', 1), ('branch', 1)]
